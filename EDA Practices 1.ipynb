# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('D:\\Data Science\\iNeuron\\ML\\EDA&FE\\Datasets\\data1\\Travel.csv')
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (4888, 20)

# %%
#Missing values
df.isnull().columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
#get the clear idea those are the colmns are having the null values by using the heatmap
sns.heatmap(df.isnull(),data=df,cmap='viridis',cbar=False,yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
#get the num values
num_values = [feature for feature in df.columns if df[feature].dtypes!='O']
df[num_values]
# Out:
#       CustomerID  ProdTaken   Age  CityTier  DurationOfPitch  \
# 0         200000          1  41.0         3              6.0
# 1         200001          0  49.0         1             14.0
# 2         200002          1  37.0         1              8.0
# 3         200003          0  33.0         1              9.0
# 4         200004          0   NaN         1              8.0
# ...          ...        ...   ...       ...              ...
# 4883      204883          1  49.0         3              9.0
# 4884      204884          1  28.0         1             31.0
# 4885      204885          1  52.0         3             17.0
# 4886      204886          1  19.0         3             16.0
# 4887      204887          1  36.0         1             14.0
#
#       NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# 0                          3                3.0                    3.0
# 1                          3                4.0                    4.0
# ...

# %%
df_num=df[num_values]
df_num
# Out:
#       CustomerID  ProdTaken   Age  CityTier  DurationOfPitch  \
# 0         200000          1  41.0         3              6.0
# 1         200001          0  49.0         1             14.0
# 2         200002          1  37.0         1              8.0
# 3         200003          0  33.0         1              9.0
# 4         200004          0   NaN         1              8.0
# ...          ...        ...   ...       ...              ...
# 4883      204883          1  49.0         3              9.0
# 4884      204884          1  28.0         1             31.0
# 4885      204885          1  52.0         3             17.0
# 4886      204886          1  19.0         3             16.0
# 4887      204887          1  36.0         1             14.0
#
#       NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# 0                          3                3.0                    3.0
# 1                          3                4.0                    4.0
# ...

# %%
#get the cat values
cat_values = [feature for feature in df.columns if df[feature].dtypes=='O']
df[cat_values]
# Out:
#         TypeofContact      Occupation  Gender ProductPitched MaritalStatus  \
# 0        Self Enquiry        Salaried  Female         Deluxe        Single
# 1     Company Invited        Salaried    Male         Deluxe      Divorced
# 2        Self Enquiry     Free Lancer    Male          Basic        Single
# 3     Company Invited        Salaried  Female          Basic      Divorced
# 4        Self Enquiry  Small Business    Male          Basic      Divorced
# ...               ...             ...     ...            ...           ...
# 4883     Self Enquiry  Small Business    Male         Deluxe     Unmarried
# 4884  Company Invited        Salaried    Male          Basic        Single
# 4885     Self Enquiry        Salaried  Female       Standard       Married
# 4886     Self Enquiry  Small Business    Male          Basic        Single
# 4887     Self Enquiry        Salaried    Male          Basic     Unmarried
#
#          Designation
# 0            Manager
# 1            Manager
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
df.describe().T
# Out:
#                            count           mean          std       min  \
# CustomerID                4888.0  202443.500000  1411.188388  200000.0
# ProdTaken                 4888.0       0.188216     0.390925       0.0
# Age                       4662.0      37.622265     9.316387      18.0
# CityTier                  4888.0       1.654255     0.916583       1.0
# DurationOfPitch           4637.0      15.490835     8.519643       5.0
# NumberOfPersonVisiting    4888.0       2.905074     0.724891       1.0
# NumberOfFollowups         4843.0       3.708445     1.002509       1.0
# PreferredPropertyStar     4862.0       3.581037     0.798009       3.0
# NumberOfTrips             4748.0       3.236521     1.849019       1.0
# Passport                  4888.0       0.290917     0.454232       0.0
# PitchSatisfactionScore    4888.0       3.078151     1.365792       1.0
# OwnCar                    4888.0       0.620295     0.485363       0.0
# ...

# %%
#change the unstable data to unique data in gender column
df['Gender'].replace('Fe Male', 'Female',inplace=True)

# %%
#validate whether do we have any fe male data or not
df['Gender'].isin(['Fe Male']).sum()
# Out:
# 0

# %% [markdown]
# # univariate analysis

# %%
sns.distplot(df['Age'],kde=False)
# Out:
# C:\Users\subas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age'>

# %%
sns.countplot(df['Gender'])
# Out:
# C:\Users\subas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(df['TypeofContact'])
# Out:
# C:\Users\subas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TypeofContact', ylabel='count'>

# %%
#understand the tpc based on gender
sns.countplot(x='TypeofContact',hue='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='TypeofContact', ylabel='count'>

# %%
#try to draw count plot for all the numerical feature columns
#for var in num_values:
   # sns.countplot(df[var])
    #plt.show()

# %%
df['Occupation']
# Out:
# 0             Salaried
# 1             Salaried
# 2          Free Lancer
# 3             Salaried
# 4       Small Business
#              ...
# 4883    Small Business
# 4884          Salaried
# 4885          Salaried
# 4886    Small Business
# 4887          Salaried
# Name: Occupation, Length: 4888, dtype: object

# %%
self_enq = df.loc[df['TypeofContact']=='Self Enquiry']
self_enq
# Out:
#       CustomerID  ProdTaken   Age TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0  Self Enquiry         3              6.0
# 2         200002          1  37.0  Self Enquiry         1              8.0
# 4         200004          0   NaN  Self Enquiry         1              8.0
# 6         200006          0  59.0  Self Enquiry         1              9.0
# 7         200007          0  30.0  Self Enquiry         1             30.0
# ...          ...        ...   ...           ...       ...              ...
# 4882      204882          1  37.0  Self Enquiry         2             20.0
# 4883      204883          1  49.0  Self Enquiry         3              9.0
# 4885      204885          1  52.0  Self Enquiry         3             17.0
# 4886      204886          1  19.0  Self Enquiry         3             16.0
# 4887      204887          1  36.0  Self Enquiry         1             14.0
#
# ...

# %%
cmp_enq=df.loc[df['TypeofContact']=='Company Invited']
cmp_enq
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 1         200001          0  49.0  Company Invited         1             14.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 5         200005          0  32.0  Company Invited         1              8.0
# 8         200008          0  38.0  Company Invited         1             29.0
# 17        200017          0  22.0  Company Invited         1             22.0
# ...          ...        ...   ...              ...       ...              ...
# 4868      204868          1  43.0  Company Invited         2             15.0
# 4872      204872          1  35.0  Company Invited         1             24.0
# 4875      204875          1  36.0  Company Invited         1              8.0
# 4877      204877          1  39.0  Company Invited         1             16.0
# 4884      204884          1  28.0  Company Invited         1             31.0
#
# ...

# %%
self_enq.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         169
# TypeofContact                 0
# CityTier                      0
# DurationOfPitch             141
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            30
# ProductPitched                0
# PreferredPropertyStar        22
# MaritalStatus                 0
# NumberOfTrips               102
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     57
# Designation                   0
# MonthlyIncome               138
# dtype: int64

# %%
cmp_enq.isnull().sum()
# Out:
# CustomerID                   0
# ProdTaken                    0
# Age                         57
# TypeofContact                0
# CityTier                     0
# DurationOfPitch             85
# Occupation                   0
# Gender                       0
# NumberOfPersonVisiting       0
# NumberOfFollowups           15
# ProductPitched               0
# PreferredPropertyStar        4
# MaritalStatus                0
# NumberOfTrips               38
# Passport                     0
# PitchSatisfactionScore       0
# OwnCar                       0
# NumberOfChildrenVisiting     9
# Designation                  0
# MonthlyIncome               70
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
null_enq=df['TypeofContact'].isnull()
df[null_enq]
# Out:
#       CustomerID  ProdTaken   Age TypeofContact  CityTier  DurationOfPitch  \
# 224       200224          0  31.0           NaN         1              NaN
# 571       200571          0  26.0           NaN         1              NaN
# 572       200572          0  29.0           NaN         1              NaN
# 576       200576          0  27.0           NaN         3              NaN
# 579       200579          0  34.0           NaN         1              NaN
# 598       200598          1  28.0           NaN         1              NaN
# 622       200622          0  32.0           NaN         3              NaN
# 724       200724          0  24.0           NaN         1              NaN
# 843       200843          0  26.0           NaN         1              NaN
# 1021      201021          1  25.0           NaN         3              NaN
# 1047      201047          0  33.0           NaN         3              NaN
# ...

# %%
#droping the null values rows
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %%
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 5         200005          0  32.0  Company Invited         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
#box plot
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='TypeofContact',y='MonthlyIncome',palette='winter',data=df)
# Out:
# <AxesSubplot:xlabel='TypeofContact', ylabel='MonthlyIncome'>

# %%
#outlier by pythonic method
#IQR=Q3-Q1=75-25=50-inter quartile range
#Q3 = 75/100*(n+1)
#Q1 = 25/100(n+1)
#upper fence & Lower fence
#upper fence = Q3+1.5*IQR
#lower fence = Q1-1,5*IQR

# %%
#take 25 % of Q1 
q1 = df['MonthlyIncome'].quantile(0.25)
q1
# Out:
# 20751.0

# %%
#take 75 % of Q1 
q3 = df['MonthlyIncome'].quantile(0.75)
q3
# Out:
# 25301.0

# %%
iqr = q3-q1
iqr
# Out:
# 4550.0

# %%
upper_limit = q3+1.5*(iqr)
upper_limit
# Out:
# 32126.0

# %%
lower_limit = q1-1.5*(iqr)
lower_limit
# Out:
# 13926.0

# %%
#get the outleir values from the math score
#find any values are there from below lower fence
df[df['MonthlyIncome']<lower_limit]
# Out:
#       CustomerID  ProdTaken   Age TypeofContact  CityTier  DurationOfPitch  \
# 142       200142          0  38.0  Self Enquiry         1              9.0
# 2586      202586          0  39.0  Self Enquiry         1             10.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 142   Large Business  Female                       2                3.0
# 2586  Large Business  Female                       3                4.0
#
#      ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 142          Deluxe                    3.0        Single            4.0
# 2586         Deluxe                    3.0        Single            5.0
#
#       Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 142          1                       5       0                       0.0
# 2586         1                       5       0                       1.0
#
#      Designation  MonthlyIncome
# 142      Manager         1000.0
# ...

# %%
#find any values are there from above upper fence
df[df['MonthlyIncome']>upper_limit]
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 25        200025          0  53.0     Self Enquiry         1             11.0
# 29        200029          0  46.0     Self Enquiry         3              8.0
# 45        200045          1  41.0     Self Enquiry         1             18.0
# 62        200062          0  50.0     Self Enquiry         1             13.0
# 105       200105          0  59.0  Company Invited         2              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4751      204751          0  41.0  Company Invited         1             16.0
# 4752      204752          1  43.0  Company Invited         3             19.0
# 4828      204828          1  56.0  Company Invited         3              9.0
# 4859      204859          1  51.0  Company Invited         3             19.0
# 4876      204876          1  52.0     Self Enquiry         3             34.0
#
# ...

# %%
#def function to get all the things for outliers
def find_all(df,clmn_name,q1_range,q3_range):
    global Upper_fence
    global Lower_fence
    q1 = df[clmn_name].quantile(q1_range)
    q3 = df[clmn_name].quantile(q3_range)
    IQR = q3-q1
    Upper_fence = q3+1.5*(IQR)
    Lower_fence = q1-1.5*(IQR)
    return IQR,Upper_fence,Lower_fence

# %%
#get all the details(IQR,upper&lower fence)
find_all(df,'MonthlyIncome',0.25,0.75)
# Out:
# (4550.0, 32126.0, 13926.0)

# %%
#get all the details(IQR,upper&lower fence)
find_all(df,'CustomerID',0.25,0.75)
# Out:
# (2427.5, 207389.5, 197679.5)

# %%
def outlier_threshold(df,variable):
    qq1 = df[variable].quantile(0.25)
    qq2 = df[variable].quantile(0.75)
    iqr = qq2-qq1
    up_fence = qq2+1.5*(iqr)
    low_fence = qq1-1.5*(iqr)
    return up_fence,low_fence

# %%
#get the outliers of the monthlyincome column
outlier_threshold(df,'MonthlyIncome')
# Out:
# (32126.0, 13926.0)

# %%
#lets runn it for all num column
for variable in num_values:
    upper_fence,lower_fence=  outlier_threshold(df,variable)
    print(variable,':','upper_fence is :',upper_fence,'and','lower_fence is',lower_fence)
# Out:
# CustomerID : upper_fence is : 207389.5 and lower_fence is 197679.5
# ProdTaken : upper_fence is : 0.0 and lower_fence is 0.0
# Age : upper_fence is : 61.0 and lower_fence is 13.0
# CityTier : upper_fence is : 6.0 and lower_fence is -2.0
# DurationOfPitch : upper_fence is : 36.5 and lower_fence is -7.5
# NumberOfPersonVisiting : upper_fence is : 4.5 and lower_fence is 0.5
# NumberOfFollowups : upper_fence is : 5.5 and lower_fence is 1.5
# PreferredPropertyStar : upper_fence is : 5.5 and lower_fence is 1.5
# NumberOfTrips : upper_fence is : 7.0 and lower_fence is -1.0
# Passport : upper_fence is : 2.5 and lower_fence is -1.5
# PitchSatisfactionScore : upper_fence is : 7.0 and lower_fence is -1.0
# OwnCar : upper_fence is : 2.5 and lower_fence is -1.5
# NumberOfChildrenVisiting : upper_fence is : 3.5 and lower_fence is -0.5
# MonthlyIncome : upper_fence is : 32126.0 and lower_fence is 13926.0

# %%
#lets find the outliers of all the columns
for variable in num_values:
    upper_outlier = df[df[variable]>upper_fence]
    lower_outlier = df[df[variable]<lower_fence]
    print(upper_outlier,lower_outlier)
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 5         200005          0  32.0  Company Invited         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
#try to plot the box plot for all the numerical features
for feature in num_values:
    sns.boxplot(df[feature])
    plt.show()
# Out:
# C:\Users\subas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\subas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\subas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # FINDING THE OUTIERS BY USING THE Z SCORE
# #source :https://www.youtube.com/watch?v=rzR_cKnkD18

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#find the outleirs with the help of z score
outliers = []
def find_outliers(col_name):
    thresold=3 #which is denote as 3rd standard deviation
    mean = np.mean(df[col_name])
    std= np.std(df[col_name])
    
    #define the loops to find the outliers combined with mean and std for all the data
    for i in df[col_name]:
        z_score = (i-mean)/std
        if np.abs(z_score)>thresold: #z score should be lessthan of all the data that is called proper data
            outliers.append(i)
    return outliers

# %%
#find outliers of all the columns with the help of z score
final_outliers = find_outliers('MonthlyIncome')
print(final_outliers)
outliers.clear() # to clear the outleirs lists from the variable to avoid duplicates
# Out:
# [1000.0, 98678.0, 38223.0, 4678.0, 38244.0, 38304.0, 38264.0, 38291.0, 38223.0, 38215.0, 38244.0, 38304.0]

# %%
#find the outliers of all the numerical columns by using loops
for num_var in df_num:
    num_outliers = find_outliers(num_var)
    print(num_var,'outliers are ',num_outliers)
    outliers.clear()# to clear the outleirs lists from the variable to avoid duplicates
    #removing or timming the outliers
# Out:
# CustomerID outliers are  []
# ProdTaken outliers are  []
# Age outliers are  []
# CityTier outliers are  []
# DurationOfPitch outliers are  [127.0]
# NumberOfPersonVisiting outliers are  []
# NumberOfFollowups outliers are  []
# PreferredPropertyStar outliers are  []
# NumberOfTrips outliers are  [19.0, 21.0, 20.0, 22.0]
# Passport outliers are  []
# PitchSatisfactionScore outliers are  []
# OwnCar outliers are  []
# NumberOfChildrenVisiting outliers are  []
# MonthlyIncome outliers are  [1000.0, 98678.0, 38223.0, 4678.0, 38244.0, 38304.0, 38264.0, 38291.0, 38223.0, 38215.0, 38244.0, 38304.0]

# %%
#trim the outleirs
new_df = df.loc[(df['MonthlyIncome']<upper_fence)&(df['MonthlyIncome']>lower_fence)]
df=new_df

# %%
df[df['MonthlyIncome']<lower_fence]
# Out:
# Empty DataFrame
# Columns: [CustomerID, ProdTaken, Age, TypeofContact, CityTier, DurationOfPitch, Occupation, Gender, NumberOfPersonVisiting, NumberOfFollowups, ProductPitched, PreferredPropertyStar, MaritalStatus, NumberOfTrips, Passport, PitchSatisfactionScore, OwnCar, NumberOfChildrenVisiting, Designation, MonthlyIncome]
# Index: []

# %%
df[df['MonthlyIncome']>upper_fence]
# Out:
# Empty DataFrame
# Columns: [CustomerID, ProdTaken, Age, TypeofContact, CityTier, DurationOfPitch, Occupation, Gender, NumberOfPersonVisiting, NumberOfFollowups, ProductPitched, PreferredPropertyStar, MaritalStatus, NumberOfTrips, Passport, PitchSatisfactionScore, OwnCar, NumberOfChildrenVisiting, Designation, MonthlyIncome]
# Index: []

# %%
#find the outliers of all the numerical columns by using loops
for num_var in df_num:
    num_outliers = find_outliers(num_var)
    print(num_var,'outliers are ',num_outliers)
    outliers.clear()# to clear the outleirs lists from the variable to avoid duplicates
    #removing or timming the outliers
# Out:
# CustomerID outliers are  []
# ProdTaken outliers are  []
# Age outliers are  []
# CityTier outliers are  []
# DurationOfPitch outliers are  [127.0]
# NumberOfPersonVisiting outliers are  []
# NumberOfFollowups outliers are  []
# PreferredPropertyStar outliers are  []
# NumberOfTrips outliers are  [19.0, 21.0, 20.0, 22.0]
# Passport outliers are  []
# PitchSatisfactionScore outliers are  []
# OwnCar outliers are  []
# NumberOfChildrenVisiting outliers are  []
# MonthlyIncome outliers are  []

# %%
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 5         200005          0  32.0  Company Invited         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
#violin plot
sns.violinplot(data = df_num)
# Out:
# <AxesSubplot:>

# %%
#heatmap for the correlation between the all of the variable
sns.heatmap(df_num.corr(),annot = True,cmap='icefire',linewidths=0.3,cbar=False)
figure = plt.gcf()
figure.set_size_inches(15,10)
plt.title("corr between variable",color ='black',size=5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#pair plot
plt.figure(figsize=(25,20))
sns.pairplot(df_num)
